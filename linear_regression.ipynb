# %%
import pandas as pd
from numba import njit
import numpy as np
import time
from random import randint
from datetime import datetime


import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from pylab import rcParams

from sklearn.linear_model import LinearRegression
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from collections import Counter

# %%
plt.figsize = 5, 5
sns.set_style("whitegrid")

# %% [markdown]
# #### Reading the data

# %%
data =  pd.read_csv("../Data/iphone_purchase_records.csv")

# %%
df =  pd.DataFrame(data)
df.dropna()
# Out:
#      Gender  Age  Salary  Purchase Iphone
# 0      Male   19   19000                0
# 1      Male   35   20000                0
# 2    Female   26   43000                0
# 3    Female   27   57000                0
# 4      Male   19   76000                0
# ..      ...  ...     ...              ...
# 395  Female   46   41000                1
# 396    Male   51   23000                1
# 397  Female   50   20000                1
# 398    Male   36   33000                0
# 399  Female   49   36000                1
#
# [400 rows x 4 columns]

# %%
#checking the correlation
df.corr()
# Out:
#                       Age    Salary  Purchase Iphone
# Age              1.000000  0.155238         0.622454
# Salary           0.155238  1.000000         0.362083
# Purchase Iphone  0.622454  0.362083         1.000000

# %%
df['Gender'] = (df['Gender'] == 'Female').astype(i

# %%
sns.relplot(data=df, x='Age', y='Salary', hue='Purchase Iphone')
plt.show()

# %% [markdown]
# ### Spliting the data into training and tesing data

# %%
x = df[["Age", "Gender"]]
y = df["Salary"]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %% [markdown]
# #### Fiting the model

# %%
reg=  LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
r2_score(y_test, y_pred)
# Out:
# 0.019032328736439008

# %%
A countuor plot for

# %%
sns.kdeplot(data=df, y=df["Age"], x=df["Salary"])
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='Age'>
